# %%
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install sklearn
# %pip install scipy
# %pip install statsmodels
# %pip install tqdm
# %pip install minio

# %%
import pandas as pd
import io
from minio import Minio
import json
from IPython.display import display

FILE_NAME = "pistacho.json"
BUCKET_FROM_NAME = "landing-zone"

# Connect to MinIO
minio_client = Minio(
    "localhost:9000",
    access_key="minio",
    secret_key="minio123",
    secure=False
)
# Get data from MinIO
data = minio_client.get_object(
    BUCKET_FROM_NAME, FILE_NAME).read().decode("utf-8")
json_data = json.loads(data)
display(json_data)
df_parcel = pd.DataFrame(json_data['Exploitation Parcel'])
# {'FarmHolder': {'Name': 'PISTACYL S.L',
#    'Identifier_Code': [{'Type': 'N. Registro de Explotaciones Autonomico',
#      'Code': '0847030810'}],
#    'Address': {'Street': 'LAGARTILLOS,2',
#     'Village': 'POZAL DE GALLINAS',
#     'Province': 'VALLADOLID',
#     'ZIP': '47450'},
#    'Phone': ['637812948'],
#    'Email': ''},
#   'HeatlhAdvisor': [{'HAd_Id': '37',
#     'Name': 'NAVAS GARRIDO, VICTOR',
#     'NIF_Code': '12342065N',
#     'ROPO_Code': '07/47/05604',
#     'Carnet Type': 'Basic'}],
df_farm = pd.json_normalize(json_data['Farm'], record_path=['FarmHolder'], meta=['Farm_Id'])
display(df_farm.describe())
df_parcel.describe()
# Out:
# {'Farm': {'FarmHolder': {'Name': 'PISTACYL S.L',
#    'Identifier_Code': [{'Type': 'N. Registro de Explotaciones Autonomico',
#      'Code': '0847030810'}],
#    'Address': {'Street': 'LAGARTILLOS,2',
#     'Village': 'POZAL DE GALLINAS',
#     'Province': 'VALLADOLID',
#     'ZIP': '47450'},
#    'Phone': ['637812948'],
#    'Email': ''},
#   'HeatlhAdvisor': [{'HAd_Id': '37',
#     'Name': 'NAVAS GARRIDO, VICTOR',
#     'NIF_Code': '12342065N',
#     'ROPO_Code': '07/47/05604',
#     'Carnet Type': 'Basic'},
#    {'HAd_Id': '67',
#     'Name': 'PAREDES GARCIA JUAN RAMON',
#     'NIF_Code': '12343911H',
#     'ROPO_Code': '07/47/05604',
#     'Carnet Type': 'Basic'},
#    {'HAd_Id': '57',
#     'Name': 'PEREZ HERAS,CARLOS',
#     'NIF_Code': '12337236J',
#     'ROPO_Code': '07/47/01256',
#     'Carnet Type': 'Basic'},
#    {'HAd_Id': '73',
#     'Name': 'VELASCO PEREZ DAVID',
#     'NIF_Code': '71181253W',
#     'ROPO_Code': '07/47/05604',
#     'Carnet Type': 'Basic'}]},
#  'HeatlhApplicator': [{'HAp_Id': '42',
#    'Description': 'ATOMIZADOR BALVEN 1500AR E0349BCR',
#    'ROMA_Code': '475050006598',
#    'Adquisition_Date': '30/12/2015',
#    'Last_Inspection_Date': '09/05/2019'},
#   {'HAp_Id': '55',
#    'Description': 'ATOMIZADOR E0351BCR',
#    'ROMA_Code': '475050006597',
#    'Adquisition_Date': '30/12/2015',
#    'Last_Inspection_Date': '17/06/2019'},
#   {'HAp_Id': '56',
#    'Description': 'ATOMIZADOR E3428BGY',
#    'IROMA_Code': '475050009441',
#    'Adquisition_Date': '10/08/2018',
#    'Last_Inspection_Date': '14/08/2018'},
#   {'HAp_Id': '52',
#    'Description': 'BOMBA INYECTORA FERTIRRIGACION 200 L',
#    'ROMA_Code': '',
#    'Adquisition_Date': '',
#    'Last_Inspection_Date': ''}],
#  'Exploitation Parcel': [{'Parcel_Id': '29',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '96',
#      'Municipality_Name': 'MORALEJA DE LAS PANADERAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '5',
#     'Parcel': '20',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '13.63',
#    'Used_Area': '13.63',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '27',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '5',
#     'Parcel': '5170',
#     'Enclosure': '2'},
#    'Use': 'TA',
#    'Official_Area': '0.73',
#    'Used_Area': '0.73',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '27',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '4',
#     'Parcel': '560',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '2.14',
#    'Used_Area': '2.14',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '26',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '5',
#     'Parcel': '585',
#     'Enclosure': '2'},
#    'Use': 'VI',
#    'Official_Area': '1.46',
#    'Used_Area': '1.46',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '26',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '5',
#     'Parcel': '5221',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '3.4',
#    'Used_Area': '3.4',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '26',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '5',
#     'Parcel': '5226',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '1.12',
#    'Used_Area': '1.12',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '28',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '1',
#     'Parcel': '70',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '4.35',
#    'Used_Area': '4.35',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '28',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '1',
#     'Parcel': '71',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '0.81',
#    'Used_Area': '0.81',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '28',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '1',
#     'Parcel': '74',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '5.34',
#    'Used_Area': '5.34',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '28',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '124',
#      'Municipality_Name': 'POZAL DE GALLINAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '1',
#     'Parcel': '77',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '2.17',
#    'Used_Area': '2.17',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'},
#   {'Parcel_Id': '30',
#    'CAP_Code': {'Province': {'Province_Code': '47', 'Province_Name': ''},
#     'Municipality': {'Municipality_Code': '96',
#      'Municipality_Name': 'MORALEJA DE LAS PANADERAS'},
#     'Agregate': '',
#     'Zone': '',
#     'Polygon': '5',
#     'Parcel': '25',
#     'Enclosure': '1'},
#    'Use': 'FS',
#    'Official_Area': '6.07',
#    'Used_Area': '6.07',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Rainfed_Irrigated': 'Irrigated',
#    'Protected_Area?': 'N'}],
#  'Phytosanitary_Action': [{'Parcel_Id': '28',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '04/03/2021',
#    'Problem': 'MOJANTE',
#    'Area': '12',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '28',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '4/03/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '12',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '4',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '29',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '05/03/2021',
#    'Problem': 'MOJANTE',
#    'Area': '14.67',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '29',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '05/03/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '14.67',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '4',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '29',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '08/03/2021',
#    'Problem': 'MOJANTE',
#    'Area': '14.67',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '29',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '09/03/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '14.67',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '4',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '27',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '11/03/2021',
#    'Problem': 'MOJANTE',
#    'Area': '4',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '27',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '11/03/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '4',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '4',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '30',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '11/03/2021',
#    'Problem': 'MOJANTE',
#    'Area': '12.8',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '30',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '11/03/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '12.8',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '4',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '26',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '29/03/2021',
#    'Problem': 'ALTERNARIA',
#    'Area': '4.97',
#    'HAd_Id': '37',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '24039',
#     'Commercial_Name': 'CUPROSAN WG'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '27',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '29/03/2021',
#    'Problem': 'ALTERNARIA',
#    'Area': '4',
#    'HAd_Id': '37',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '24039',
#     'Commercial_Name': 'CUPROSAN WG'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '28',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '29/03/2021',
#    'Problem': 'ALTERNARIA',
#    'Area': '12',
#    'HAd_Id': '37',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '24039',
#     'Commercial_Name': 'CUPROSAN WG'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '29',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '30/03/2021',
#    'Problem': 'ALTERNARIA',
#    'Area': '14.67',
#    'HAd_Id': '37',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '24039',
#     'Commercial_Name': 'CUPROSAN WG'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '30',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '30/03/2021',
#    'Problem': 'ALTERNARIA',
#    'Area': '12.8',
#    'HAd_Id': '37',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '24039',
#     'Commercial_Name': 'CUPROSAN WG'},
#    'Dosage': '1',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '28',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '06/05/2021',
#    'Problem': 'PULGONES',
#    'Area': '12',
#    'HAd_Id': '73',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25882',
#     'Commercial_Name': 'Stamina®'},
#    'Dosage': '0.06',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '28',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '07/05/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '12',
#    'HAd_Id': '67',
#    'HAp_Id': '55',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '8',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '26',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '14/05/2021',
#    'Problem': 'PULGONES',
#    'Area': '4.97',
#    'HAd_Id': '73',
#    'HAp_Id': '56',
#    'Phytosanitary': {'Registration_Number': '25882',
#     'Commercial_Name': 'Stamina®'},
#    'Dosage': '0.06',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '27',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '14/05/2021',
#    'Problem': 'PULGONES',
#    'Area': '4',
#    'HAd_Id': '73',
#    'HAp_Id': '56',
#    'Phytosanitary': {'Registration_Number': '25882',
#     'Commercial_Name': 'Stamina®'},
#    'Dosage': '0.06',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '29',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '14/05/2021',
#    'Problem': 'PULGONES',
#    'Area': '14.67',
#    'HAd_Id': '73',
#    'HAp_Id': '56',
#    'Phytosanitary': {'Registration_Number': '25882',
#     'Commercial_Name': 'Stamina®'},
#    'Dosage': '0.06',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '28',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '17/05/2021',
#    'Problem': 'ESCLEROTINIA',
#    'Area': '12',
#    'HAd_Id': '73',
#    'HAp_Id': '56',
#    'Phytosanitary': {'Registration_Number': '',
#     'Commercial_Name': 'CONTANS WG'},
#    'Dosage': '2',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '26',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '26/05/2021',
#    'Problem': 'ESCLEROTINIA',
#    'Area': '4.97',
#    'HAd_Id': '73',
#    'HAp_Id': '56',
#    'Phytosanitary': {'Registration_Number': '',
#     'Commercial_Name': 'CONTANS WG'},
#    'Dosage': '2',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '27',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '26/05/2021',
#    'Problem': 'ESCLEROTINIA',
#    'Area': '4',
#    'HAd_Id': '73',
#    'HAp_Id': '56',
#    'Phytosanitary': {'Registration_Number': '',
#     'Commercial_Name': 'CONTANS WG'},
#    'Dosage': '2',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '28',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '23/07/2021',
#    'Problem': 'MOJANTE',
#    'Area': '12',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '0.2',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '28',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '23/07/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '12',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '8',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '29',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '27/07/2021',
#    'Problem': 'MOJANTE',
#    'Area': '14.67',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '0.2',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '29',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '27/07/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '14.67',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '8',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '30',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '29/07/2021',
#    'Problem': 'MOJANTE',
#    'Area': '12.8',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '0.2',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '30',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '29/07/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '12.8',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '8',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '26',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '30/07/2021',
#    'Problem': 'MOJANTE',
#    'Area': '4.97',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '0.2',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '26',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '30/07/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '4.97',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '6',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '27',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '02/08/2021',
#    'Problem': 'MOJANTE',
#    'Area': '4',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': 'NO_FITO',
#     'Commercial_Name': 'SUPORTER'},
#    'Dosage': '0.2',
#    'Efficacy': 'Good'},
#   {'Parcel_Id': '27',
#    'Crop': {'Species': 'PISTACHO', 'Variety': 'KERMAN'},
#    'Date': '02/08/2021',
#    'Problem': 'MALAS HIERBAS VIVACES',
#    'Area': '4',
#    'HAd_Id': '67',
#    'HAp_Id': '42',
#    'Phytosanitary': {'Registration_Number': '25449',
#     'Commercial_Name': 'THOR GOLD'},
#    'Dosage': '6',
#    'Efficacy': 'Good'}]}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb Cell 2 line 3
#      <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a> df_parcel = pd.DataFrame(json_data['Exploitation Parcel'])
#      <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a> # {'FarmHolder': {'Name': 'PISTACYL S.L',
#      <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=23'>24</a> #    'Identifier_Code': [{'Type': 'N. Registro de Explotaciones Autonomico',
#      <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=24'>25</a> #      'Code': '0847030810'}],
#    (...)
#      <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=34'>35</a> #     'ROPO_Code': '07/47/05604',
#      <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=35'>36</a> #     'Carnet Type': 'Basic'}],
# ---> <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=36'>37</a> df_farm = pd.json_normalize(json_data['Farm'], record_path=['FarmHolder'], meta=['Farm_Id'])
#      <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=37'>38</a> display(df_farm.describe())
#      <a href='vscode-notebook-cell:/Users/topopelon/Documents/GemeloDigital/analysis/sources.ipynb#W1sZmlsZQ%3D%3D?line=38'>39</a> df_parcel.describe()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:517, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     514                 meta_vals[key].append(meta_val)
#     515             records.extend(recs)
# --> 517 _recursive_extract(data, record_path, {}, level=0)
#     519 result = DataFrame(records)
#     521 if record_prefix is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:499, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     497 else:
#     498     for obj in data:
# --> 499         recs = _pull_records(obj, path[0])
#     500         recs = [
#     501             nested_to_record(r, sep=sep, max_level=max_level)
#     502             if isinstance(r, dict)
#     503             else r
#     504             for r in recs
#     505         ]
#     507         # For repeating the metadata later
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/json/_normalize.py:429, in json_normalize.<locals>._pull_records(js, spec)
#     427         result = []
#     428     else:
# --> 429         raise TypeError(
#     430             f"{js} has non list value {result} for path {spec}. "
#     431             "Must be list or null."
#     432         )
#     433 return result
#
# TypeError: {'FarmHolder': {'Name': 'PISTACYL S.L', 'Identifier_Code': [{'Type': 'N. Registro de Explotaciones Autonomico', 'Code': '0847030810'}], 'Address': {'Street': 'LAGARTILLOS,2', 'Village': 'POZAL DE GALLINAS', 'Province': 'VALLADOLID', 'ZIP': '47450'}, 'Phone': ['637812948'], 'Email': ''}, 'HeatlhAdvisor': [{'HAd_Id': '37', 'Name': 'NAVAS GARRIDO, VICTOR', 'NIF_Code': '12342065N', 'ROPO_Code': '07/47/05604', 'Carnet Type': 'Basic'}, {'HAd_Id': '67', 'Name': 'PAREDES GARCIA JUAN RAMON', 'NIF_Code': '12343911H', 'ROPO_Code': '07/47/05604', 'Carnet Type': 'Basic'}, {'HAd_Id': '57', 'Name': 'PEREZ HERAS,CARLOS', 'NIF_Code': '12337236J', 'ROPO_Code': '07/47/01256', 'Carnet Type': 'Basic'}, {'HAd_Id': '73', 'Name': 'VELASCO PEREZ DAVID', 'NIF_Code': '71181253W', 'ROPO_Code': '07/47/05604', 'Carnet Type': 'Basic'}]} has non list value {'Name': 'PISTACYL S.L', 'Identifier_Code': [{'Type': 'N. Registro de Explotaciones Autonomico', 'Code': '0847030810'}], 'Address': {'Street': 'LAGARTILLOS,2', 'Village': 'POZAL DE GALLINAS', 'Province': 'VALLADOLID', 'ZIP': '47450'}, 'Phone': ['637812948'], 'Email': ''} for path FarmHolder. Must be list or null.

# %%
df_parcel.dtypes
# Out:
# Parcel_Id            object
# CAP_Code             object
# Use                  object
# Official_Area        object
# Used_Area            object
# Crop                 object
# Rainfed_Irrigated    object
# Protected_Area?      object
# dtype: object

# %%
# Show missing values
df_parcel.isnull().sum()
# Out:
# Parcel_Id            0
# CAP_Code             0
# Use                  0
# Official_Area        0
# Used_Area            0
# Crop                 0
# Rainfed_Irrigated    0
# Protected_Area?      0
# dtype: int64

# %%
# Melt CAP_Code and Crop columns
display(df_parcel['CAP_Code'][0])
display(df_parcel['Crop'][0])
# Crop column
df_parcel['Crop_Species'] = df_parcel['Crop'].apply(
    lambda x: x['Species'])
df_parcel['Crop_Variety'] = df_parcel['Crop'].apply(
    lambda x: x['Variety'])
# Drop Crop column
df_parcel.drop(columns=['Crop'], inplace=True)
df_parcel
# CAP_Code column
df_parcel['CAP_Code'] = df_parcel['CAP_Code'].apply(
    lambda x: f'{x["Province"]["Province_Code"]}-{x["Municipality"]["Municipality_Code"]}-{x["Agregate"]}-{x["Zone"]}-{x["Polygon"]}-{x["Parcel"]}-{x["Enclosure"]}')
# Put 0s between tow -
df_parcel['CAP_Code'] = df_parcel['CAP_Code'].apply(
    lambda x: x.replace('---', '-0-0-'))
df_parcel
# Out:
# {'Province': {'Province_Code': '47', 'Province_Name': ''},
#  'Municipality': {'Municipality_Code': '96',
#   'Municipality_Name': 'MORALEJA DE LAS PANADERAS'},
#  'Agregate': '',
#  'Zone': '',
#  'Polygon': '5',
#  'Parcel': '20',
#  'Enclosure': '1'}
# {'Species': 'PISTACHO', 'Variety': 'KERMAN'}
#    Parcel_Id             CAP_Code Use Official_Area Used_Area Rainfed_Irrigated Protected_Area? Crop_Species Crop_Variety
# 0         29     47-96-0-0-5-20-1  FS         13.63     13.63         Irrigated               N     PISTACHO       KERMAN
# 1         27  47-124-0-0-5-5170-2  TA          0.73      0.73         Irrigated               N     PISTACHO       KERMAN
# 2         27   47-124-0-0-4-560-1  FS          2.14      2.14         Irrigated               N     PISTACHO       KERMAN
# 3         26   47-124-0-0-5-585-2  VI          1.46      1.46         Irrigated               N     PISTACHO       KERMAN
# 4         26  47-124-0-0-5-5221-1  FS           3.4       3.4         Irrigated               N     PISTACHO       KERMAN
# 5         26  47-124-0-0-5-5226-1  FS          1.12      1.12         Irrigated               N     PISTACHO       KERMAN
# 6         28    47-124-0-0-1-70-1  FS          4.35      4.35         Irrigated               N     PISTACHO       KERMAN
# 7         28    47-124-0-0-1-71-1  FS          0.81      0.81         Irrigated               N     PISTACHO       KERMAN
# 8         28    47-124-0-0-1-74-1  FS          5.34      5.34         Irrigated               N     PISTACHO       KERMAN
# 9         28    47-124-0-0-1-77-1  FS          2.17      2.17         Irrigated               N     PISTACHO       KERMAN
# 10        30     47-96-0-0-5-25-1  FS          6.07      6.07         Irrigated               N     PISTACHO       KERMAN
